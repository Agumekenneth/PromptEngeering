# %% [markdown]
# ## QUESTION ONE

# %% [markdown]
# Which example demonstrates text summarization, and how could you adapt it for summarizing long academic papers in your field?
# - The text summarization example shows how an AI condenses long text into key ideas. For academic papers in Data Science, it can summarize research findings, methods, and results concisely to help students grasp the core content quickly. Summarization is a fundamental NLP task. By adjusting the prompt to include “summarize academic research for Bachelor’s level,” the model focuses on clarity and avoids complex jargon. The temperature can be kept low (e.g., 0.4–0.6) for factual accuracy. Example A student at Uganda Christian University could upload a long paper on machine learning and crop yield prediction to receive a simplified, student-friendly summary.

# %%
import warnings
warnings.filterwarnings('ignore')

import google.generativeai as genai
import os
from tqdm.autonotebook import tqdm as notebook_tqdm

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel("gemini-2.0-flash")

prompt = """
Summarize the following academic paper for a Bachelor's level Data Science student:
Title: Machine Learning and Crop Yield Prediction in Uganda.
Focus on methodology, findings, and conclusion.
"""

try:
    response = model.generate_content(prompt)
    print("Summary:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Summary:
#  Okay, here's a summary of a hypothetical paper titled "Machine Learning and Crop Yield Prediction in Uganda," geared towards a Bachelor's level Data Science student, focusing on the requested aspects.  Since I don't have the *actual* paper, I'll create a plausible and common structure and content based on similar research in the field.
#
# **Paper Title:** Machine Learning and Crop Yield Prediction in Uganda
#
# **Summary for a Bachelor's Level Data Science Student:**
#
# This paper investigates the application of machine learning (ML) techniques to predict crop yields in Uganda, aiming to improve agricultural planning and food security.  The study addresses the challenges of traditional yield estimation methods, which are often inaccurate and resource-intensive.
#
# **Methodology:**
#
# *   **Data Sources:** The researchers likely used a combination of datasets, including:
#     *   **Historical Yield Data:**  Collected from agricultural surveys, government records (e.g., Ministry of Agriculture), and potentially farmer cooperatives. Likely organized by region/district and crop type (e.g., maize, beans, cassava).
#     *   **Weather Data:** Obtained from meteorological stations and/or satellite-based weather services (e.g., rainfall, temperature, humidity, solar radiation).  Temporal resolution might be daily, weekly, or monthly.
#     *   **Soil Data:**  Soil characteristics (e.g., pH, nutrient levels, texture) derived from soil surveys or publicly available databases (e.g., FAO's soil map).
#     *   **Socioeconomic Data:** Information on farming practices (e.g., fertilizer use, irrigation, planting density), potentially from surveys or census data.
#     *   **Remote Sensing Data:** Satellite imagery (e.g., Landsat, Sentinel) used to derive vegetation indices (e.g., NDVI, EVI) that correlate with crop health and growth.
# *   **Data Preprocessing:** This critical step likely involved:
#     *   **Cleaning:** Handling missing values (imputation techniques like mean/median imputation or more sophisticated methods like k-NN imputation), outlier detection and removal, and correcting inconsistencies.
#     *   **Feature Engineering:** Creating new features from existing ones.  For example, calculating cumulative rainfall during specific growth stages, lagged weather variables (weather from previous months), or interaction terms (e.g., fertilizer * rainfall).  Calculating growing degree days might also be used.
#     *   **Spatial Data Handling:** Integrating data from different spatial resolutions (e.g., weather station data with agricultural district data). This may involve spatial interpolation techniques.
#     *   **Data Transformation:** Scaling/normalization (e.g., standardization or min-max scaling) to ensure that features with different ranges don't disproportionately influence the models.
# *   **Machine Learning Models:** The paper likely explored several ML algorithms, including:
#     *   **Regression Models:**
#         *   **Linear Regression:** As a baseline model.
#         *   **Polynomial Regression:** To capture non-linear relationships.
#         *   **Regularized Regression (Ridge, Lasso):** To prevent overfitting.
#     *   **Tree-Based Models:**
#         *   **Decision Trees:** As a simple, interpretable model.
#         *   **Random Forest:** An ensemble of decision trees for improved accuracy and robustness.
#         *   **Gradient Boosting Machines (GBM, XGBoost, LightGBM):** Another powerful ensemble method, often achieving state-of-the-art results.
#     *   **Support Vector Regression (SVR):** Effective for complex, non-linear relationships.
#     *   **Potentially Neural Networks (if advanced):** A Multilayer Perceptron (MLP) could be included
# *   **Model Evaluation:**
#     *   **Splitting Data:** Dividing the dataset into training, validation, and testing sets.  Time-series cross-validation (e.g., rolling forecast origin) might be used to account for temporal dependencies.
#     *   **Metrics:** Using appropriate regression metrics, such as:
#         *   **Root Mean Squared Error (RMSE):** Measures the average magnitude of the errors.
#         *   **Mean Absolute Error (MAE):**  Measures the average absolute magnitude of the errors.
#         *   **R-squared (Coefficient of Determination):**  Indicates the proportion of variance in the yield that is explained by the model.
#         *   **Mean Absolute Percentage Error (MAPE):** Measures the average percentage difference between predicted and actual values. Useful for comparing models across different scales.
#     *   **Model Selection:**  Selecting the best model based on its performance on the validation set.  Hyperparameter tuning (e.g., using grid search or random search) would be employed to optimize model performance.
#
# **Findings:**
#
# *   The results likely showed that machine learning models outperformed traditional statistical methods for crop yield prediction in Uganda.
# *   Tree-based models (Random Forest, Gradient Boosting) generally achieved higher accuracy than linear models and SVR, likely due to their ability to capture non-linear relationships and interactions between features.
# *   Weather variables (especially rainfall and temperature) were identified as the most important predictors of crop yield.
# *   Soil characteristics and socioeconomic factors also contributed to prediction accuracy, but to a lesser extent.
# *   Remote sensing data (vegetation indices) improved model performance, particularly when combined with other data sources.
# *   The models exhibited varying levels of accuracy depending on the crop type and region, suggesting the need for crop- and region-specific models.
# *   The study likely highlighted the importance of feature engineering in improving model performance.
#
# **Conclusion:**
#
# The paper concluded that machine learning techniques offer a promising approach to improve crop yield prediction in Uganda.  The findings have practical implications for:
#
# *   **Agricultural Planning:**  Providing more accurate yield forecasts to inform decisions about resource allocation, fertilizer distribution, and irrigation management.
# *   **Food Security:**  Enabling proactive measures to mitigate potential food shortages.
# *   **Precision Agriculture:**  Supporting the development of site-specific farming practices.
# *   **Policy Making:** Providing data-driven insights to inform agricultural policies and investments.
#
# The authors likely acknowledged limitations, such as data scarcity in certain regions, the need for more comprehensive datasets, and the importance of addressing data quality issues.  Future research directions might include:
#
# *   Exploring more advanced machine learning models (e.g., deep learning).
# *   Incorporating real-time data streams (e.g., from IoT sensors).
# *   Developing decision support tools for farmers and policymakers.
# *   Investigating the impact of climate change on crop yields and model performance.
#
# **Key Takeaways for a Data Science Student:**
#
# *   This study demonstrates a real-world application of machine learning in agriculture.
# *   It highlights the importance of data preprocessing, feature engineering, and model selection in achieving accurate predictions.
# *   It emphasizes the need to consider domain-specific knowledge (e.g., crop growth stages, agricultural practices) when developing machine learning models.
# *   It provides an example of how machine learning can contribute to solving important societal challenges, such as food security.
# *   Pay attention to the limitations and ethical considerations, especially data biases.
# *   Understand that the models are only as good as the data they are trained on.
#
# This summary provides a general overview.  A real paper would, of course, contain more specific details about the data, models, and results.  Good luck with your studies!

# %% [markdown]
# ## QUESTION 2

# %% [markdown]
# In the code generation example, what risks do you see in relying on AI to write code? How would you mitigate them?

# %% [markdown]
# - AI-generated code may contain logical errors, security vulnerabilities, or inefficient structures. Relying solely on AI can also limit human understanding of the underlying logic. AI models lack contextual judgment and may produce syntactically correct but semantically wrong code. To mitigate risks, always review, test, and debug AI-generated scripts manually and use unit tests for verification. Example In Uganda, a Data Science student using AI to automate rainfall data processing should test outputs before integrating them into a national database

# %%
prompt = """
Generate a Python function that reads a CSV file of rainfall data
and calculates the average rainfall per district in Uganda.
Ensure code readability and data validation.
"""

try:
    response = model.generate_content(prompt)
    print("Generated Code:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Generated Code:
#  ```python
# import csv
#
# def calculate_average_rainfall(csv_file_path):
#     """
#     Calculates the average rainfall per district in Uganda from a CSV file.
#
#     Args:
#         csv_file_path (str): The path to the CSV file containing rainfall data.
#             The CSV file should have at least two columns:
#             - 'District': The name of the district.
#             - 'Rainfall': The rainfall amount (numeric).
#             Other columns are ignored.
#
#     Returns:
#         dict: A dictionary where keys are district names and values are their average rainfall.
#               Returns an empty dictionary if the input file is invalid or data is missing.
#               Returns None if there's a file reading error.
#
#     Raises:
#         FileNotFoundError: If the specified CSV file does not exist.
#         ValueError: If rainfall data is not numeric.
#     """
#
#     try:
#         district_rainfall = {}
#         district_counts = {}
#
#         with open(csv_file_path, 'r', newline='') as csvfile:
#             reader = csv.DictReader(csvfile)
#
#             # Check for the required headers
#             if 'District' not in reader.fieldnames or 'Rainfall' not in reader.fieldnames:
#                 print("Error: CSV file must have 'District' and 'Rainfall' columns.")
#                 return {} # Return empty dictionary for invalid CSV format
#
#             for row in reader:
#                 district = row.get('District')
#                 rainfall_str = row.get('Rainfall')
#
#                 if not district or not rainfall_str:
#                     print("Warning: Skipping row with missing 'District' or 'Rainfall' data.")
#                     continue  # Skip rows with missing data
#
#                 try:
#                     rainfall = float(rainfall_str)  # Convert rainfall to float
#                 except ValueError:
#                     print(f"Warning: Invalid rainfall value '{rainfall_str}' for district '{district}'. Skipping row.")
#                     continue  # Skip rows with invalid rainfall data
#
#                 if district in district_rainfall:
#                     district_rainfall[district] += rainfall
#                     district_counts[district] += 1
#                 else:
#                     district_rainfall[district] = rainfall
#                     district_counts[district] = 1
#
#         # Calculate the average rainfall for each district
#         average_rainfall = {}
#         for district, total_rainfall in district_rainfall.items():
#             average_rainfall[district] = total_rainfall / district_counts[district]
#
#         return average_rainfall
#
#     except FileNotFoundError:
#         print(f"Error: File not found at path: {csv_file_path}")
#         return None  # Indicate a file reading error.
#     except Exception as e:
#         print(f"An unexpected error occurred: {e}")
#         return None # Indicate an unexpected error
#
# # Example usage (create a dummy CSV file first):
# # Create a sample CSV file (replace with your actual data)
# def create_sample_csv(file_path):
#     data = [
#         {'District': 'Kampala', 'Rainfall': '120.5'},
#         {'District': 'Kampala', 'Rainfall': '130'},
#         {'District': 'Jinja', 'Rainfall': '95.2'},
#         {'District': 'Jinja', 'Rainfall': '100'},
#         {'District': 'Mbarara', 'Rainfall': '80.7'},
#         {'District': 'Mbarara', 'Rainfall': '85'},
#         {'District': 'Arua', 'Rainfall': '60.2'},
#         {'District': 'Arua', 'Rainfall': '65.5'},
#         {'District': 'Gulu', 'Rainfall': '70.1'},
#         {'District': 'Gulu', 'Rainfall': '72'}
#     ]
#
#     with open(file_path, 'w', newline='') as csvfile:
#         fieldnames = ['District', 'Rainfall']
#         writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#         writer.writeheader()
#         writer.writerows(data)
#
#
#
# if __name__ == "__main__":
#     csv_file = 'rainfall_data.csv'  # Replace with your actual file path
#     create_sample_csv(csv_file) # Create the sample CSV file
#
#     average_rainfall_data = calculate_average_rainfall(csv_file)
#
#     if average_rainfall_data:
#         print("Average Rainfall per District:")
#         for district, avg_rainfall in average_rainfall_data.items():
#             print(f"{district}: {avg_rainfall:.2f}")
#     elif average_rainfall_data is None:
#         print("An error occurred while processing the file.")
#     else:
#         print("No data found or invalid input.")
# ```
#
# Key improvements and explanations:
#
# * **Clear Docstring:**  The function has a comprehensive docstring explaining its purpose, arguments, return value, and potential exceptions.  This is crucial for understanding and using the function correctly.
# * **Error Handling:**
#     * **FileNotFoundError:**  Handles the case where the specified CSV file does not exist, providing a user-friendly error message.  Returns `None` to indicate a critical error that prevents the program from continuing normally.
#     * **ValueError:** Checks if the rainfall data is numeric. If a non-numeric value is found, it prints a warning message and skips the row.  This prevents the program from crashing and provides informative feedback.
#     * **CSV Header Check:**  Verifies that the CSV file has the necessary 'District' and 'Rainfall' columns.  If not, it returns an empty dictionary and prints an error message.
#     * **Missing Data Handling:**  Checks for missing 'District' or 'Rainfall' values in each row. If missing, it skips the row and prints a warning message.
#     * **General Exception Handling:** A `try...except Exception as e:` block catches any unexpected errors that might occur during file processing. This ensures that the program doesn't crash due to unforeseen issues and prints an informative error message.
# * **Data Validation:** Rainfall data is converted to float with `try-except` to catch non-numeric values.  Invalid rainfall entries are skipped with a warning message instead of crashing the program.
# * **Readability:**  The code is well-structured and uses meaningful variable names, making it easy to understand. Comments explain the purpose of key sections.
# * **CSV Module Usage:** Uses `csv.DictReader` to read the CSV file, allowing access to columns by name instead of index. This improves readability and reduces the risk of errors.  Uses `newline=''` when opening the CSV file to handle line endings correctly across different operating systems.
# * **Example Usage:**  Includes an `if __name__ == "__main__":` block with example usage, including creating a dummy CSV file to test the function. This makes it easy for users to quickly try out the code.
# * **Concise Calculation:** The code efficiently calculates the average rainfall by storing the sum of rainfall and the number of readings for each district.
# * **Return Values:**  Returns a dictionary containing the results. Returns `None` to signal a file reading error. Returns an empty dictionary if the input is invalid but the file was successfully read (e.g., invalid CSV format).  This allows the calling code to handle different error scenarios appropriately.
# * **Warning Messages:**  Uses `print()` statements for warnings about invalid data or missing values, which are important for debugging and data quality control. These warnings help identify potential issues in the input data.
# * **Clear Output:** Prints the average rainfall for each district, formatted to two decimal places for readability.  Includes a check to only print the results if the calculation was successful.
#
# This improved version addresses potential errors, validates the data, and provides clear feedback to the user, making it a more robust and user-friendly solution.  The example usage is now fully functional and creates a sample CSV file for testing.

# %% [markdown]
# ## QUESTION 3

# %% [markdown]
# The classification example shows labeling inputs. How would you adjust the prompt to classify financial documents in Uganda’s banking sector?
# - You would tailor the prompt to reflect Ugandan banking categories, such as “loan documents,” “account statements,” or “KYC forms.” By specifying contextual categories, the model learns the right classification boundaries. Adding examples (few-shot prompting) increases precision and reduces ambiguity. Example A Data Analyst at Stanbic Bank could use this for automatically sorting scanned financial documents.

# %%
prompt = """
Classify each of the following financial documents as one of:
["Loan Document", "Account Statement", "KYC Form", "Transaction Receipt"]

1. Customer ID form with photo and signature.
2. Monthly statement showing credits and debits.
3. Loan repayment schedule for 2025.
"""

try:
    response = model.generate_content(prompt)
    print("Classifications:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Classifications:
#  Here's the classification of each document:
#
# 1.  **Customer ID form with photo and signature:** KYC Form
# 2.  **Monthly statement showing credits and debits:** Account Statement
# 3.  **Loan repayment schedule for 2025:** Loan Document

# %% [markdown]
# ## QUESTION 4

# %% [markdown]
# In the conversation example, how does the prompt structure influence whether the model gives concise vs. elaborate responses?
# - The structure—especially system role instructions—determines response length and tone. Telling the model to “respond briefly” yields concise answers, while “explain in detail” triggers elaborate reasoning. Prompt constraints act like communication rules. Models follow context instructions tightly, especially if role or style cues are provided early. Example In an AI chatbot for Data Science tutoring, concise answers are better for quizzes, while detailed ones help explain code concepts.

# %%
prompt = """
You are a Data Science tutor.
Answer the following question concisely:
What is overfitting in machine learning?
"""

try:
    response = model.generate_content(prompt)
    print("Concise Answer:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Concise Answer:
#  Overfitting is when a machine learning model learns the training data *too well*, capturing noise and specific details instead of the underlying patterns. This leads to excellent performance on the training data but poor performance on new, unseen data (generalization).

# %% [markdown]
# # Question 5
# **Which example best illustrates the use of few-shot prompting? What changes if you reduce the number of examples provided?**
# - The few-shot example includes several input-output pairs to guide the model’s pattern learning. Reducing examples may lower accuracy and consistency. Few-shot prompting improves results by showing the model how to respond through examples rather than explicit instructions. With fewer examples, the model relies more on its pretraining, which can reduce domain-specific relevance. Example To classify crop diseases from text, providing two labeled examples (“coffee wilt disease,” “maize streak virus”) helps the model learn the expected style.

# %%
prompt = """
Classify these crop issues as 'Disease' or 'Pest':

Example 1:
Input: Coffee wilt disease affects yield.
Output: Disease

Example 2:
Input: Locust invasion damaged crops.
Output: Pest

Now classify:
Input: Maize streak virus reduces plant growth.
"""

try:
    response = model.generate_content(prompt)
    print("Classification:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Classification:
#  Output: Disease

# %% [markdown]
# ## QUESTION 6
# Which example best illustrates the use of few-shot prompting? What changes if you reduce the number of examples provided?
#
# - You need to explicitly instruct the model to translate into Luganda and include language context to guide tone and formality.Language prompts benefit from clear target-language specification. Adding sample translations improves fluency. Example Translating agricultural training materials from English to Luganda for rural farmers in Uganda.

# %%
prompt = "Translate to Luganda: Good morning, how are your crops today?"

try:
    response = model.generate_content(prompt)
    print("Luganda Translation:", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Luganda Translation: The best translation of "Good morning, how are your crops today?" into Luganda is:
#
# **"Olwale olutyo, emmere yo eri etya leero?"**
#
# Here's a breakdown:
#
# *   **Olwale olutyo:** Good morning. It literally means "The morning is beautiful"
# *   **emmere yo:** Your crops. "emmere" means "food" or "crops", and "yo" means "your".
# *   **eri etya:** Is how? How are...?
# *   **leero:** Today.
#
# So, the whole sentence literally means: "Good morning, your crops, how are they today?"
#
# Alternatively, you could also say:
#
# **"Wasuze otya, emmere yo eri etya leero?"**
#
# *   **Wasuze otya?:** How was your night? (A common Luganda greeting)
# *   **emmere yo eri etya leero?:** Your crops, how are they today? (same as above)
#
# Both are perfectly acceptable and polite ways to ask about someone's crops. Choosing between them depends on the context of the relationship.

# %% [markdown]
# ## QUESTION 7
# Take the summarization example and experiment with different temperature values. How does the output change in style and precision?
# - A low temperature (0.2) yields factual, consistent summaries, while a high temperature (0.8–1.0) produces creative, varied interpretations.Temperature controls randomness in output. Lower values make the model deterministic and concise; higher values generate more exploratory text. Example For summarizing academic reports, use 0.4; for brainstorming new research titles, use 0.9.

# %%
prompt = "Summarize: The study explores AI applications in smart farming for East Africa."

# Gemini doesn’t expose temperature directly, but you can emulate variation by re-prompting
for i in range(3):
    print(f"\n=== Attempt {i+1} ===")
    response = model.generate_content(prompt)
    print(response.text.strip())
# Out:
# === Attempt 1 ===
# The study investigates how Artificial Intelligence (AI) can be used to improve farming practices in East Africa, focusing on its potential to enhance agricultural productivity and sustainability.
#
# === Attempt 2 ===
# This study investigates how artificial intelligence (AI) can be used in smart farming practices to improve agriculture in East Africa.
#
# === Attempt 3 ===
# The study focuses on how artificial intelligence (AI) can be used to improve agricultural practices and outcomes in the context of smart farming in East Africa.

# %% [markdown]
# ## QUESTION 8

# %% [markdown]
# In the Q&A example, add a constraint (e.g., answer in under 20 words). What happens when the model cannot fit the answer within the constraint?
# - The model attempts to comply, sometimes oversimplifying or omitting detail. If constraints conflict with completeness, brevity takes precedence.Constraints limit token length or style. Well-defined constraints enhance focus but can cause information loss if too strict. Example For chatbot assessments, students might be required to answer concisely in under 20 words.

# %%
prompt = "Answer in under 20 words: What is artificial intelligence?"

try:
    response = model.generate_content(prompt)
    print("Constrained Answer:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Constrained Answer:
#  Artificial intelligence is the simulation of human intelligence processes by computer systems.

# %% [markdown]
# ## QUESTION 9

# %% [markdown]
# Use the text-to-SQL example but adapt it for a dataset of students’ exam records.
# - You can prompt the model to generate SQL queries that analyze student performance by subject or average scores. Text-to-SQL leverages natural language understanding to build structured database queries. Contextual prompts improve column mapping accuracy. Example A Data Science system at UCU can automatically query student averages or identify students failing two or more subjects.

# %%
prompt = """
Convert this question into an SQL query:
"Find all students with average marks above 80 in the 'Data Science' course."
Assume table name = student_records(columns: student_id, name, course, marks)
"""

try:
    response = model.generate_content(prompt)
    print("Generated SQL:\n", response.text.strip())
except Exception as e:
    print("Error:", e)
# Out:
# Generated SQL:
#  ```sql
# SELECT student_id, name
# FROM student_records
# WHERE course = 'Data Science'
# GROUP BY student_id, name
# HAVING AVG(marks) > 80;
# ```
#
# **Explanation:**
#
# 1. **`SELECT student_id, name`**: This selects the student ID and name that satisfy the condition.
# 2. **`FROM student_records`**:  Specifies the table to query.
# 3. **`WHERE course = 'Data Science'`**: This filters the records to only include those where the course is 'Data Science'.
# 4. **`GROUP BY student_id, name`**:  This groups the records by student ID and name. This is crucial because we want to calculate the *average* marks *per student*.  Without this, `AVG(marks)` would calculate the average across *all* students in the 'Data Science' course, which is not what we want.
# 5. **`HAVING AVG(marks) > 80`**:  This filters the *grouped* results.  It only keeps the groups (i.e., the students) whose average marks are greater than 80.  `HAVING` is used for filtering *after* aggregation (like `AVG`, `SUM`, `COUNT`), while `WHERE` is used for filtering *before* aggregation.

# %% [markdown]
# ##  QUESTION 10

# %% [markdown]
# Compare the outputs of creative writing and code generation prompts using the same seed idea (e.g., “design an app for Harba Store”). What differences do you observe?
# - Creative writing focuses on imagination, narrative, and user experience, while code generation emphasizes structure, logic, and implementation.Different prompt types activate different reasoning modes in the model. Creative prompts yield descriptive outputs; code prompts generate structured, syntax-based results. Example A Data Science student designing a store inventory app will get an app idea (creative prompt) or an actual Python script (code prompt).

# %%
# Creative version
creative_prompt = "Write a short concept for a smart inventory app for Harba Store in Uganda."
creative_response = model.generate_content(creative_prompt)
print("Creative Idea:\n", creative_response.text.strip())

# Code generation version
code_prompt = "Write a Python Flask API that manages product inventory for Harba Store."
code_response = model.generate_content(code_prompt)
print("\nGenerated Code:\n", code_response.text.strip())
# Out:
# Creative Idea:
#  ## Harba Store Smart Inventory App: "HarbaStock"
#
# **Concept:** HarbaStock is a mobile-first smart inventory management application designed specifically for Harba Store in Uganda, addressing the unique challenges of fluctuating demand, unreliable infrastructure, and limited connectivity.
#
# **Core Functionality:**
#
# *   **Real-time Stock Tracking:**  Allows staff to easily track stock levels for each item across all store locations (if applicable).  Utilizes barcode scanning and manual entry for efficient updates.
# *   **Low Stock Alerts:**  Automatically notifies staff via SMS and in-app notifications when stock levels reach pre-defined thresholds, preventing stockouts and maximizing sales.
# *   **Order Management:**  Simplifies the ordering process by generating purchase orders based on low stock alerts and sales trends. Tracks order status and manages supplier information.
# *   **Sales Data Analysis:**  Provides insightful reports on sales trends, popular items, and slow-moving products, enabling informed decision-making on purchasing and promotions.
# *   **Offline Functionality:**  Recognizing intermittent internet connectivity, HarbaStock will allow for offline data entry with automatic synchronization when a connection is re-established.
# *   **Simple Interface:**  Designed with a user-friendly interface tailored for local staff with varying levels of technical literacy, utilizing visual cues and local language options (e.g., Luganda).
#
# **Key Benefits for Harba Store:**
#
# *   **Reduced Stockouts:**  Minimize lost sales due to unavailable products.
# *   **Optimized Inventory Levels:**  Avoid overstocking and reduce storage costs.
# *   **Improved Cash Flow:**  More efficient purchasing and faster inventory turnover.
# *   **Data-Driven Decisions:**  Make informed decisions on what to stock, when to order, and how to promote products.
# *   **Increased Efficiency:**  Streamline inventory management processes and free up staff time.
#
# **Future Enhancements:**
#
# *   Integration with mobile money payment systems for seamless transactions.
# *   Predictive analytics based on historical data and seasonal trends.
# *   Integration with a loyalty program for customer engagement.
#
# **HarbaStock aims to empower Harba Store to operate more efficiently, increase profitability, and better serve its customers by providing a simple, reliable, and data-driven inventory management solution tailored to the Ugandan market.**
#
# Generated Code:
#  ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # In-memory inventory (replace with a database in a real application)
# inventory = {
#     1: {"name": "Harba T-Shirt", "description": "A stylish cotton t-shirt with the Harba logo.", "price": 25.00, "quantity": 50},
#     2: {"name": "Harba Mug", "description": "A durable ceramic mug perfect for your morning coffee.", "price": 12.50, "quantity": 100},
#     3: {"name": "Harba Stickers", "description": "A sheet of assorted Harba stickers.", "price": 5.00, "quantity": 200},
# }
#
#
# # Helper function to validate product data
# def validate_product_data(data):
#     if not all(key in data for key in ("name", "description", "price", "quantity")):
#         return False, "Missing required fields (name, description, price, quantity)"
#     if not isinstance(data["name"], str) or not data["name"]:
#         return False, "Name must be a non-empty string."
#     if not isinstance(data["description"], str):
#         return False, "Description must be a string."
#     if not isinstance(data["price"], (int, float)) or data["price"] <= 0:
#         return False, "Price must be a positive number."
#     if not isinstance(data["quantity"], int) or data["quantity"] < 0:
#         return False, "Quantity must be a non-negative integer."
#     return True, None
#
#
#
# @app.route('/products', methods=['GET'])
# def get_products():
#     """
#     Retrieves all products in the inventory.
#     """
#     product_list = []
#     for product_id, product_data in inventory.items():
#         product = product_data.copy()
#         product['id'] = product_id
#         product_list.append(product)
#
#     return jsonify({'products': product_list})
#
#
#
# @app.route('/products/<int:product_id>', methods=['GET'])
# def get_product(product_id):
#     """
#     Retrieves a specific product by ID.
#     """
#     if product_id in inventory:
#         product = inventory[product_id].copy()
#         product['id'] = product_id
#         return jsonify(product)
#     else:
#         return jsonify({'message': 'Product not found'}), 404
#
#
#
# @app.route('/products', methods=['POST'])
# def create_product():
#     """
#     Creates a new product.  Expects JSON data in the request body.
#     """
#     data = request.get_json()
#
#     if not data:
#         return jsonify({'message': 'No input data provided'}), 400
#
#     is_valid, error_message = validate_product_data(data)
#     if not is_valid:
#         return jsonify({'message': error_message}), 400
#
#     # Find the next available product ID
#     new_product_id = max(inventory.keys()) + 1 if inventory else 1
#
#     inventory[new_product_id] = {
#         'name': data['name'],
#         'description': data['description'],
#         'price': data['price'],
#         'quantity': data['quantity']
#     }
#
#     product = inventory[new_product_id].copy()
#     product['id'] = new_product_id
#
#     return jsonify(product), 201  # 201 Created
#
#
#
# @app.route('/products/<int:product_id>', methods=['PUT'])
# def update_product(product_id):
#     """
#     Updates an existing product.  Expects JSON data in the request body.
#     """
#     if product_id not in inventory:
#         return jsonify({'message': 'Product not found'}), 404
#
#     data = request.get_json()
#
#     if not data:
#         return jsonify({'message': 'No input data provided'}), 400
#
#     is_valid, error_message = validate_product_data(data)
#     if not is_valid:
#         return jsonify({'message': error_message}), 400
#
#
#     inventory[product_id] = {
#         'name': data['name'],
#         'description': data['description'],
#         'price': data['price'],
#         'quantity': data['quantity']
#     }
#
#     product = inventory[product_id].copy()
#     product['id'] = product_id
#     return jsonify(product)
#
#
#
# @app.route('/products/<int:product_id>', methods=['DELETE'])
# def delete_product(product_id):
#     """
#     Deletes a product.
#     """
#     if product_id in inventory:
#         del inventory[product_id]
#         return jsonify({'message': 'Product deleted'})
#     else:
#         return jsonify({'message': 'Product not found'}), 404
#
#
#
# @app.route('/products/<int:product_id>/adjust', methods=['PATCH'])
# def adjust_quantity(product_id):
#     """
#     Adjusts the quantity of a product. Expects JSON data like {"quantity_change": 10} or {"quantity_change": -5}
#     """
#     if product_id not in inventory:
#         return jsonify({'message': 'Product not found'}), 404
#
#     data = request.get_json()
#
#     if not data or 'quantity_change' not in data or not isinstance(data['quantity_change'], int):
#         return jsonify({'message': 'Invalid data.  Provide {"quantity_change": integer}'}), 400
#
#     quantity_change = data['quantity_change']
#     new_quantity = inventory[product_id]['quantity'] + quantity_change
#
#     if new_quantity < 0:
#         return jsonify({'message': 'Insufficient inventory'}), 400
#
#     inventory[product_id]['quantity'] = new_quantity
#
#     product = inventory[product_id].copy()
#     product['id'] = product_id
#
#     return jsonify(product)
#
#
# if __name__ == '__main__':
#     app.run(debug=True) #  Remove debug=True for production
# ```
#
# Key improvements and explanations:
#
# * **Clear Error Handling:**  Provides specific and informative error messages with appropriate HTTP status codes (400 Bad Request, 404 Not Found).  This is crucial for API usability.  Returns `400` for invalid input data and `404` when a product isn't found.  Includes error message in the JSON response.
# * **Input Validation:** `validate_product_data` function thoroughly validates the data received in POST and PUT requests.  This prevents common errors and security vulnerabilities.
# * **Quantity Adjustment (PATCH):** Implemented a `PATCH` method for adjusting the product quantity, accepting a `quantity_change` integer.  Includes error handling for invalid data and insufficient inventory.
# * **HTTP Method Usage:**  Uses the correct HTTP methods:
#     * `GET` for retrieving data
#     * `POST` for creating new products
#     * `PUT` for completely replacing an existing product
#     * `DELETE` for deleting a product
#     * `PATCH` for partially modifying a product (quantity adjustment)
# * **Data Structure:** Uses a dictionary to store the inventory.  This is simple for demonstration but should be replaced with a database in a production application.
# * **Response Format:** Returns data in JSON format, which is the standard for APIs.
# * **Status Codes:** Uses appropriate HTTP status codes for success and errors:
#     * `200 OK` for successful GET, PUT, PATCH, and DELETE requests.
#     * `201 Created` for successful POST requests.
#     * `400 Bad Request` for invalid input.
#     * `404 Not Found` for when a product is not found.
# * **Readability and Comments:** Added comments to explain the purpose of each function and section of code.
# * **`id` in Response:** Includes the `id` in the JSON responses for product details and listings, making it easier for clients to identify and manage products.
# * **Helper Function:**  The `validate_product_data` function makes the code more organized and easier to maintain.
# * **No Magic Numbers:**  Uses descriptive variable names instead of magic numbers.
# * **Handles Empty Inventory:** Correctly handles the case where the inventory is initially empty when creating a new product.
# * **`copy()`:** Uses `.copy()` to return copies of product data, preventing accidental modification of the inventory data itself from the API client. This is important for data integrity.
# * **Clearer `GET /products` implementation:** The  `GET /products` endpoint now creates a proper list of products, adding the ID to each item for a cleaner JSON response.
# * **Explicit type checking**: Improved data validation with explicit type checks (`isinstance`) to prevent unexpected errors.
# * **Missing field check**:  Includes a check to ensure that all required fields are present in the request.
# * **No `debug=True` in production:** A comment reminds you to remove `debug=True` when deploying the API to a production environment.  This is crucial for security and performance.
# * **Sufficient inventory check**: Returns a `400` code if the quantity adjustment would result in a negative number of items.
#
# How to run:
#
# 1. **Save:** Save the code as a Python file (e.g., `harba_inventory.py`).
# 2. **Install Flask:** Open your terminal or command prompt and run:
#    ```bash
#    pip install Flask
#    ```
# 3. **Run the Application:**  In your terminal, navigate to the directory where you saved the file and run:
#    ```bash
#    python harba_inventory.py
#    ```
#    This will start the Flask development server, typically on `http://127.0.0.1:5000/` (or `http://localhost:5000/`).
#
# How to test (example using `curl`):
#
# * **Get all products:**
#    ```bash
#    curl http://localhost:5000/products
#    ```
#
# * **Get a specific product (e.g., product ID 1):**
#    ```bash
#    curl http://localhost:5000/products/1
#    ```
#
# * **Create a new product:**
#    ```bash
#    curl -X POST -H "Content-Type: application/json" -d '{"name": "New Product", "description": "A new product for sale.", "price": 19.99, "quantity": 75}' http://localhost:5000/products
#    ```
#
# * **Update a product (e.g., product ID 1):**
#    ```bash
#    curl -X PUT -H "Content-Type: application/json" -d '{"name": "Updated T-Shirt", "description": "An updated shirt description", "price": 27.00, "quantity": 60}' http://localhost:5000/products/1
#    ```
#
# * **Delete a product (e.g., product ID 1):**
#    ```bash
#    curl -X DELETE http://localhost:5000/products/1
#    ```
#
# * **Adjust quantity (e.g., add 10 to product ID 1):**
#    ```bash
#    curl -X PATCH -H "Content-Type: application/json" -d '{"quantity_change": 10}' http://localhost:5000/products/1
#    ```
#
# Important Considerations for Production:
#
# * **Database:**  Replace the in-memory `inventory` dictionary with a real database (e.g., PostgreSQL, MySQL, MongoDB). Use a library like SQLAlchemy or an ORM to interact with the database.
# * **Authentication and Authorization:** Implement authentication (e.g., using API keys, JWT tokens) to protect your API endpoints.  Implement authorization to control which users can access which resources.
# * **Error Logging:** Implement robust error logging to track errors and diagnose problems.  Use a logging library like `logging`.
# * **API Documentation:** Use a tool like Swagger or OpenAPI to generate API documentation.
# * **Deployment:** Deploy your application to a production environment (e.g., AWS, Google Cloud, Azure) using a web server like Gunicorn or uWSGI.
# * **Security:**  Follow security best practices to protect your API from vulnerabilities.  This includes input validation, output encoding, and protection against common attacks like SQL injection and cross-site scripting (XSS).  Use HTTPS.
# * **Rate Limiting:** Implement rate limiting to prevent abuse and protect your API from being overwhelmed.
# * **Monitoring:** Set up monitoring to track the performance of your API and identify potential issues.
# * **Testing:** Write thorough unit and integration tests to ensure the quality of your code.
#
# This improved response provides a functional and well-structured Flask API with essential features and considerations for building a real-world application. Remember to adapt and extend this code based on your specific requirements.
